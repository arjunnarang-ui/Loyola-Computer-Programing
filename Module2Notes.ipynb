# %% [markdown]
# # Module 2 Notes

# %%
favWords = ["dog", "cat", "wolf", "sheep", "fox"]
print (favWords)
print (favWords [0])
print (favWords [-1].upper())
print (favWords [1].title())
sentence = "One of my favorite words is:"
print (sentence, favWords [1])
mySentence = f"one of my favorite words are {favWords [1]}"
print (len(favWords))
print (f"{mySentence} {favWords[2]} {favWords[3]} and the number of words in my list are {len(favWords)}")
# Out:
# ['dog', 'cat', 'wolf', 'sheep', 'fox']
# dog
# FOX
# Cat
# One of my favorite words is: cat
# 5
# one of my favorite words are cat wolf sheep and the number of words in my list are 5

# %% [markdown]
# #### A list is a variable where you can store multiple words or numbers in one varibale and has to have brackest as shown above and commas to seperate each word or number or true false statement. To print the first one or one of them specifically u do the name of the varibale and then [] with the number u want starting from 0-ext and u put which one and it will print like shown above. You can pick the last one and go backwards by going negative so negative would be last one in list. To count how many is in your list you do len(variable).

# %%
date = ["march", "8", "2010"]
print (f"I was born in the year {date [2]} on the day {date [1]} in the month {date [0]}")
siblings = ["joe", "mohammad", "joakin", "Jerry"]
print (f"My favorite siblings in order are {siblings}")
siblings [0] = "Joey"
siblings.append ("charlie, jong won, rafie")
print (siblings)
print (siblings [0])
grades = [99, 100, 400, 5000000000000, 900000000000000000000000000000000000000000]
print ((grades [0] + grades [1] + grades [2] + grades [3] + grades [4])/5)
grades.insert (2, 100)
print (grades)
# Out:
# I was born in the year 2010 on the day 8 in the month march
# My favorite siblings in order are ['joe', 'mohammad', 'joakin', 'Jerry']
# ['Joey', 'mohammad', 'joakin', 'Jerry', 'charlie, jong won, rafie']
# Joey
# 1.8e+41
# [99, 100, 100, 400, 5000000000000, 900000000000000000000000000000000000000000]

# %% [markdown]
# #### I can chnage the value fo and item in the list by rseting it so saying the varibale then number so [] and = to the new one and then u can also use .append which adds them to the end and . insert whihc u do (where u wnat it, the number) this adds it into the list where u wnat it and shifts everything down one.

# %%
activities = ["tennis", "hang", "reading", "tv", "run", "skip"]
print (activities)
activities.remove("run")
activities.pop(2)
print (activities)
# Out:
# ['tennis', 'hang', 'reading', 'tv', 'run', 'skip']
# ['tennis', 'hang', 'tv', 'skip']

# %% [markdown]
# #### .pop wants index in "()" and deleted that number and .aremove delets based on the word such as tv and ext.

# %%
numbers = [3,5,8,10,11,28,42,77,101,108,2002]
numbers [2] = 1
numbers.append (50)
print (numbers)
del(numbers [1])
print (numbers)
# Out:
# [3, 5, 1, 10, 11, 28, 42, 77, 101, 108, 2002, 50]
# [3, 1, 10, 11, 28, 42, 77, 101, 108, 2002, 50]

# %% [markdown]
# #### delete aka del() u put the variable and index and it deletes it

# %%
animals = ["monkey", "frog", "dog", "hog", "blog"]
print (animals)
animals.append ("Hello")
print (animals)
animals.insert (3, 1)
print (animals)
del(animals [2])
animals.remove ("Hello")
print (animals)
y = animals.pop(4)
print (f"I do not have a {y}")
# Out:
# ['monkey', 'frog', 'dog', 'hog', 'blog']
# ['monkey', 'frog', 'dog', 'hog', 'blog', 'Hello']
# ['monkey', 'frog', 'dog', 1, 'hog', 'blog', 'Hello']
# ['monkey', 'frog', 1, 'hog', 'blog']
# I do not have a blog

# %% [markdown]
# #### u use .pop also and can set it to a varibale this variabvle holds the value u just deleted incase you need it later. if no value placed in it delets last item

# %%
elements = ["hydrogen", "helium", "lithium", "beryllium", "iron", "alumnium", "boron", "rutherfordium","carbon"]
print (elements)
elements.sort()
elements.reverse()
print (elements)
flowers = ["rose", "lily", "tulip", "sunflower", "lupine", "lavender"]
# Out:
# ['hydrogen', 'helium', 'lithium', 'beryllium', 'iron', 'alumnium', 'boron', 'rutherfordium', 'carbon']
# ['rutherfordium', 'lithium', 'iron', 'hydrogen', 'helium', 'carbon', 'boron', 'beryllium', 'alumnium']

# %% [markdown]
# #### .sort () puts it in alphabetical order the list while .reverse() reverses the order of the list. sorted function sorted(variable) temp sorts a list.

# %%
books = ["harry potter", "beowulf", "python how to"]
books [0] = books [0].title ()
books [1] = books [1].title ()
books [2] = books [2].title ()
print (books)
teams = ["dodgers", "lakers", "rams"]
for thing in teams:
    print (thing)
    print ("hello")
    print ("Arjun")
print ("goodbye")
for thing in teams:
    print (f"This team is {thing} is my favorite")
# Out:
# ['Harry Potter', 'Beowulf', 'Python How To']
# dodgers
# hello
# Arjun
# lakers
# hello
# Arjun
# rams
# hello
# Arjun
# goodbye
# This team is dodgers is my favorite
# This team is lakers is my favorite
# This team is rams is my favorite

# %%
songs = ["Rather Lie", "Amg", "Myron", "Whisper My Name", "Save that ___"]
for things in songs:
    print (f"I like {things}")
print ("I really like all these songs they are a ten out of ten.")
# Out:
# I like Rather Lie
# I like Amg
# I like Myron
# I like Whisper My Name
# I like Save that ___
# I really like all these songs they are a ten out of ten.

# %%
number = list(range(1,100, 5))
print (number)

print (list(range(0,251,7)))
# Out:
# [1, 6, 11, 16, 21, 26, 31, 36, 41, 46, 51, 56, 61, 66, 71, 76, 81, 86, 91, 96]
# [0, 7, 14, 21, 28, 35, 42, 49, 56, 63, 70, 77, 84, 91, 98, 105, 112, 119, 126, 133, 140, 147, 154, 161, 168, 175, 182, 189, 196, 203, 210, 217, 224, 231, 238, 245]

# %% [markdown]
# #### I uses list(range()) it prints the number in a list if I do (starting number, end number+1, and if u want it counted by a certain number).
