# %%
print("hello")

# %% [markdown]
# ##### this is the print command in python. It will print to the console/terminal

# %%
my_name = "Arjun"
print(my_name.title())
print(my_name.upper(), my_name.lower())
# Out:
# Arjun
# ARJUN arjun

# %% [markdown]
# #### Title means first letetr in every word is capital. Upper means every letter in evry word is capatalized. Lower means all words are lowercase. Structured as variable.Lower, upper, title (). Print is the command to use it and commas seprate the two commands.

# %%
my_life="great expextations"
print(my_life.title())
# Out:
# Great Expextations

# %%
firstName = "Ajun"
lastName = "Narang" 
fullName = f"{firstName} {lastName}"
print(fullName)
print (f"Hello, {fullName.title()}!")
# Out:
# Ajun Narang
# Hello, Ajun Narang!

# %% [markdown]
# #### You can combine two strings by using f"{firstName} {lastName}" and setting it = to somehting using this it combines those two strings when u print the variable name. You have to have the f and {}.

# %%
print("grocery list: apples\nbananas\nmil\ncelery\npeanut butte\nbutter\nbread")
print("grocery list: apples\n\tbananas\n\tmil\n\tcelery\n\tpeanut butte\n\tbutter\n\tbread")
# Out:
# grocery list: apples
# bananas
# mil
# celery
# peanut butte
# butter
# bread
# grocery list: apples
# 	bananas
# 	mil
# 	celery
# 	peanut butte
# 	butter
# 	bread

# %% [markdown]
# #### if u wana use one print instead of retyping u do \n make sure forward and itll seperate it like a list. While \t adds tab. You have to do a second \ if u wna do a new line and a tab for example: \n\t

# %%
name= " Arjun Narang "
name_cleaned = name.strip().upper()
print (name_cleaned)
#print (name)
# Out:
# ARJUN NARANG

# %% [markdown]
# #### The .strip () makes it so it deletes the space there are three methods. rstrip (), lstrip(), and strip (). You can make it upper case to by adding .upper directly onto it. The # makes it comment wethre a code or just writing somehting.

# %%
name = input("enter your name")
print (name)
# Out:
# Arjun Narang

# %% [markdown]
# #### If I want a user to write something I use the input function which will let the user input whath they want shown above.
