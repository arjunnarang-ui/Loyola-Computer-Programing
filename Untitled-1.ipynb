# %%
x=41
y=57.9
z="arjun"
print(z)
print(y)
print(x)
# Out:
# arjun
# 57.9
# 41

# %% [markdown]
# ##### I created 3 variables. They are x,y, and z x is an inetegr, y is a float, and z is a string and then I used the print command to print them.

# %%
Jar1=1
Jar2=10
hello="hello"
print (jar1+jar2+hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       2 Jar2=10
#       3 hello="hello"
# ----> 4 print (jar1+jar2+hello)
#
# NameError: name 'jar1' is not defined

# %% [markdown]
# #### Error is becasue youy cant integers and strings togetehr

# %%
jar1=5
jar2=10
print(jar2)
jar2=jar1
print (jar2)
# Out:
# 10
# 5

# %% [markdown]
# #### Whatevr is on the left of the equals sign gets set to the value of the right side of the equal sign.

# %%
name = "John"
age = 8
print ("My name is",name, "and I am" , age, "years old!")
# Out:
# My name is John and I am 8 years old!

# %% [markdown]
# #### When ever u want to combine the print and variables in. betwen your write the comma it tells it to switch gears write the variable then switch to the other thing u wnated to print.
